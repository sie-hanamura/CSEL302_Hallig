# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
emails = pd.read_csv('/content/Email_Exchanges.csv', encoding='latin-1' )
emails.head()
# Out:
#          Date                            From                           To  \
# 0  2024-05-08      curator@newfieldmuseum.org  security@newfieldmuseum.org
# 1  2024-05-09     security@newfieldmuseum.org       all@newfieldmuseum.org
# 2  2024-05-10        staff@newfieldmuseum.org   curator@newfieldmuseum.org
# 3  2024-05-11      manager@newfieldmuseum.org  director@newfieldmuseum.org
# 4  2024-05-12  maintenance@newfieldmuseum.org  security@newfieldmuseum.org
#
#                               Subject  \
# 0                   Security Concerns
# 1        Reminder: Security Protocols
# 2         Suspicious Activity Noticed
# 3    Urgent: Review of Security Tapes
# 4  Service Entrance Alarm Malfunction
#
#                                                 Body
# 0  I've noticed an increase in visitors lingering...
# 1  Please ensure all staff are reminded of the ne...
# 2  Several visitors have been spotted near the Sa...
# 3  Can we review the security tapes from the last...
# ...

# %%
inventory = pd.read_csv('/content/Inventory_Records.csv', encoding='latin-1' )
inventory.head()
# Out:
#   Item ID           Description    Last Known Location Movement Date  \
# 0   SP001      Sapphire Phoenix  Ancient World Exhibit    2024-05-09
# 1   SP002  Golden Falcon Statue         Treasure Trove    2024-05-07
# 2   SP003       Emerald Serpent          Reptile Realm    2024-05-08
# 3   SP004         Platinum Lion      Kingdom of Beasts    2024-05-10
# 4   SP005       Diamond Unicorn     Mythical Creatures    2024-05-06
#
#   Authorized Personnel
# 0             John Doe
# 1           Jane Smith
# 2          Emily White
# 3        Michael Brown
# 4         Olivia Green
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
security = pd.read_csv('/content/Security_Camera_Logs.csv', encoding='latin-1' )
security.head()
# Out:
#   Camera ID          Location            Timestamp Detected Movement  \
# 0      C101         Main Hall  2024-05-10 11:00 PM               Yes
# 1      C102   Ancient Exhibit  2024-05-10 11:05 PM                No
# 2      C103         East Wing  2024-05-11 10:00 AM               Yes
# 3      C104  Gemstone Gallery  2024-05-11 02:00 PM               Yes
# 4      C105         Main Hall  2024-05-12 09:15 AM               Yes
#
#               Notable Observations
# 0           Shadowy figure spotted
# 1                                -
# 2  Visitor lingered unusually long
# 3     Suspicious behavior observed
# 4                    Group entered

# %%
visitor = pd.read_csv('/content/Visitor_Logs.csv', encoding='latin-1' )
visitor.head()
# Out:
#          Date Entry Time Exit Time Visitor ID        Exhibit Visited
# 0  2024-05-10   10:00 AM  02:00 PM      V1234  Ancient World Exhibit
# 1  2024-05-10   10:15 AM  03:00 PM      V1235  Ancient World Exhibit
# 2  2024-05-11   11:00 AM  01:30 PM      V1236       Gemstone Gallery
# 3  2024-05-11   01:00 PM  04:00 PM      V1237  Ancient World Exhibit
# 4  2024-05-12   09:00 AM  01:00 PM      V1238  Ancient World Exhibit

# %%
unusual_visitor = visitor.describe()
unusual_visitor.head()
# Out:
#               Date Entry Time Exit Time Visitor ID        Exhibit Visited
# count            9          9         9          9                      9
# unique           5          9         7          9                      2
# top     2024-05-10   10:00 AM  03:00 PM      V1234  Ancient World Exhibit
# freq             2          1         2          1                      7

# %%
hidden_message = emails.describe()
hidden_message.head()
# Out:
#               Date                        From                           To  \
# count            5                           5                            5
# unique           5                           5                            4
# top     2024-05-08  curator@newfieldmuseum.org  security@newfieldmuseum.org
# freq             1                           1                            2
#
#                   Subject                                               Body
# count                   5                                                  5
# unique                  5                                                  5
# top     Security Concerns  I've noticed an increase in visitors lingering...
# freq                    1                                                  1

# %%
anomaly_detection = security.describe()
anomaly_detection
# Out:
#        Camera ID   Location            Timestamp Detected Movement  \
# count          9          9                    9                 9
# unique         9          4                    9                 2
# top         C101  Main Hall  2024-05-10 11:00 PM               Yes
# freq           1          3                    1                 7
#
#        Notable Observations
# count                     9
# unique                    8
# top                       -
# freq                      2

# %%
missing_inventory = inventory.describe()
missing_inventory.head()
# Out:
#        Item ID       Description    Last Known Location Movement Date  \
# count        5                 5                      5             5
# unique       5                 5                      5             5
# top      SP001  Sapphire Phoenix  Ancient World Exhibit    2024-05-09
# freq         1                 1                      1             1
#
#        Authorized Personnel
# count                     5
# unique                    5
# top                John Doe
# freq                      1

# %% [markdown]
# Missing inventory is item Sapphire Phoenix, Item ID: SP001. Last known location is Ancient World Exhibit and movement date is 2024-05-09.	The authorized Personnel for this item is: John Doe. Item is moved on 5/09/24.
#
# On the date of 5/10/2024, an unusual visitor arrived at 10:00 am and exited at 3:00 pm. The exhibit visited is Ancient World Exhibit, and  the visitor ID is V1234. In the visitor logs, this user's exit time is 2:00 PM. While visitor V1325 is 3:00pm , there is a possibility that these two switched IDs.
#
# Ancient World Exhbit Visitors
# 5/10 - 10:00 AM - 2:00 PM - V1234
# 5/10 - 10:15 AM - 3:00 PM, - V1235
#
# Two days before this, 5/08/2024, Security concerns in Sapphire Phoenix are raised.
#
# In the emails:
# 5/08/24 - **Increase in visitors lingering Sapphire Phoenix.**
# 5/09/24 - **New security prtocols applied.**
# 5/10/24 - **Several visitors spotted near Saphire Phoenix (Day Item went missing.)**
# 5/11/24 - **Security tapes review.**
# 5/12/24 - **Alarm at service entrance malfunctioned. Went off twice last night w/ no reason.**
#
# On the security cameras, an anomaly is detected on 2024-05-10 11:00 PM on camera C101. And the location is the Main Hall. Movement is detected and a Shadowy figure is spotted. This is when the item went missing.
#
# Anomaly Detections:
# 5/10/2024, 11:00 PM (Camera C101) - **Shadowy figure spotted on Main Hall.**
# 5/11/2024, 10:00 AM, 2:00 PM - **Suspicous behabior in GemStone Gallery.**
# 5/12/2024, 10:45 AM - Unattended bag spotted
# 5/13/2024, 2:45 PM - Visitor taking photos
# 5/13/2024, 3:30 PM - Visitor avoided camera
#
# GemStone Gallery Visitors
# 5/11 - 11:00 AM - 1:30 PM - V1236
# 5/13 - 3:00

# %% [markdown]
# Suspects are John Doe, V136, V137, and V140. The Phoenexi Sapphire is already a popular item before it went missing. It did not leave museum on 8/11 but was moved around in a hidden place before they went back and took it 2 days later on the 8/13. That's why alarms went off the night before and the entrance was malfunctioning.
